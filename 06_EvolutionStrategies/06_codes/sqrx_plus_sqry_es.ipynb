# %%
import numpy as np

# Fungsi objektif yang ingin diminimalkan
def objective_function(X):
    x, y = X
    return x**2 + y**2

# Parameter ES
mu = 3  # Ukuran populasi induk
lmbda = 6  # Jumlah keturunan
generations = 100  # Jumlah generasi
bounds = [(-5, 5), (-5, 5)]  # Batas pencarian untuk setiap variabel
initial_step_size = 2  # Langkah awal untuk mutasi

# Inisialisasi populasi induk
def initialize_population(mu, bounds, step_size):
    population = []
    step_sizes = []
    for _ in range(mu):
        individual = [np.random.uniform(low, high) for (low, high) in bounds]
        population.append(individual)
        step_sizes.append(step_size)  # Set step size awal yang sama untuk setiap individu
    return np.array(population), np.array(step_sizes)

# ES algoritma utama
def evolution_strategies(objective_function, bounds, mu, lmbda, generations, initial_step_size):
    # Inisialisasi populasi induk dan ukuran langkah
    population, step_sizes = initialize_population(mu, bounds, initial_step_size)
    print(population)
    for gen in range(generations):
        offspring = []
        offspring_step_sizes = []

        # Menghasilkan keturunan melalui mutasi
        for i in range(lmbda):
            # Pilih secara acak satu induk dari populasi
            parent_index = np.random.randint(0, mu)
            parent = population[parent_index]
            step_size = step_sizes[parent_index]

            # Mutasi (self-adaptation)
            new_step_size = step_size * np.exp(np.random.normal(0, 1) * 0.1)
            child = parent + new_step_size * np.random.normal(0, 1, len(bounds))
            
            # Membatasi anak dalam batas yang diizinkan
            child = np.clip(child, [b[0] for b in bounds], [b[1] for b in bounds])
            
            offspring.append(child)
            offspring_step_sizes.append(new_step_size)
        
        # Evaluasi keturunan
        offspring = np.array(offspring)
        offspring_step_sizes = np.array(offspring_step_sizes)
        scores = np.array([objective_function(ind) for ind in offspring])

        # Seleksi: Memilih mu individu terbaik dari lambda keturunan
        selected_indices = scores.argsort()[:mu]
        population = offspring[selected_indices]
        step_sizes = offspring_step_sizes[selected_indices]
        
        # Output hasil setiap generasi
        best_individual = population[0]
        best_score = objective_function(best_individual)
        print(f"Generation {gen+1}: Best Score = {best_score}, Best Individual = {best_individual}")

    # Hasil akhir
    best_individual = population[np.argmin([objective_function(ind) for ind in population])]
    best_score = objective_function(best_individual)
    return best_individual, best_score

# Jalankan algoritma
best_individual, best_score = evolution_strategies(objective_function, bounds, mu, lmbda, generations, initial_step_size)
print("\nBest solution:", best_individual)
print("Best objective function value:", best_score)
# Out:
# [[ 0.10958085 -4.37616828]
#  [-4.22216604  0.40165651]
#  [ 4.7477284   4.12749671]]
# Generation 1: Best Score = 0.6999969467886524, Best Individual = [-0.52969318 -0.64762804]
# Generation 2: Best Score = 2.7353102605576654, Best Individual = [-1.2188715  -1.11788306]
# Generation 3: Best Score = 1.2479183796363178, Best Individual = [0.68624248 0.88147016]
# Generation 4: Best Score = 0.153389123755577, Best Individual = [-0.04179422 -0.38941285]
# Generation 5: Best Score = 0.8876533666359826, Best Individual = [0.87370115 0.35256158]
# Generation 6: Best Score = 0.6050670710530222, Best Individual = [-0.76801038  0.12339826]
# Generation 7: Best Score = 7.612166244785935, Best Individual = [2.72548027 0.4288631 ]
# Generation 8: Best Score = 2.6924053653744195, Best Individual = [ 0.43917973 -1.5809891 ]
# Generation 9: Best Score = 5.326479886065711, Best Individual = [-1.91791234 -1.2837804 ]
# Generation 10: Best Score = 1.9866077837951224, Best Individual = [0.14063985 1.40243653]
# Generation 11: Best Score = 0.400698088017121, Best Individual = [0.59402738 0.2186997 ]
# Generation 12: Best Score = 2.8982262695507783, Best Individual = [0.25563382 1.68311545]
# Generation 13: Best Score = 0.060173063711983485, Best Individual = [-0.24524699  0.00519392]
# Generation 14: Best Score = 8.483636003034725, Best Individual = [2.65375    1.20051944]
# Generation 15: Best Score = 3.0729831304707247, Best Individual = [1.00828897 1.43399319]
# Generation 16: Best Score = 5.740438113282905, Best Individual = [2.28234248 0.72893822]
# Generation 17: Best Score = 6.18690653071637, Best Individual = [1.52927675 1.96168784]
# Generation 18: Best Score = 6.1862285841194105, Best Individual = [-2.13215327 -1.28068381]
# Generation 19: Best Score = 5.45507090333467, Best Individual = [-2.28169629  0.49893179]
# Generation 20: Best Score = 5.311237793050554, Best Individual = [-1.97341498 -1.19032394]
# Generation 21: Best Score = 3.143561776396717, Best Individual = [-0.03506043 -1.77266256]
# Generation 22: Best Score = 1.4287868564003903, Best Individual = [ 1.11713571 -0.42519956]
# Generation 23: Best Score = 1.55557528191705, Best Individual = [-1.17591236 -0.4156987 ]
# Generation 24: Best Score = 1.1787144701253933, Best Individual = [-0.9686522   0.49033395]
# Generation 25: Best Score = 1.4257810653062606, Best Individual = [-1.16209445  0.27444042]
# Generation 26: Best Score = 1.568059982359933, Best Individual = [0.40338886 1.18546928]
# Generation 27: Best Score = 0.20980756419549407, Best Individual = [ 0.4335122  -0.14790112]
# Generation 28: Best Score = 0.25417742976142116, Best Individual = [-0.09973312  0.49419706]
# Generation 29: Best Score = 1.7366868912596658, Best Individual = [-0.77352729  1.06693131]
# Generation 30: Best Score = 0.5859467046924447, Best Individual = [-0.74643331 -0.16965852]
# Generation 31: Best Score = 1.9034786658121865, Best Individual = [-0.86798212 -1.07242049]
# Generation 32: Best Score = 2.6466346917130146, Best Individual = [ 1.54729541 -0.50250532]
# Generation 33: Best Score = 0.9590874328676172, Best Individual = [0.97416179 0.10048002]
# Generation 34: Best Score = 0.4319815525508265, Best Individual = [0.63549539 0.16771155]
# Generation 35: Best Score = 1.0525059347707975, Best Individual = [-0.93255474 -0.42760683]
# Generation 36: Best Score = 1.1193100764689485, Best Individual = [ 0.85632854 -0.62129825]
# Generation 37: Best Score = 0.9217730934325215, Best Individual = [ 0.1890285  -0.94129768]
# Generation 38: Best Score = 0.034464588525851034, Best Individual = [ 0.05429903 -0.17752804]
# Generation 39: Best Score = 0.6707561876447133, Best Individual = [ 0.02079001 -0.81873315]
# Generation 40: Best Score = 1.6376510494167265, Best Individual = [0.25397245 1.25425239]
# Generation 41: Best Score = 2.2542604736493486, Best Individual = [-0.79867965  1.27136592]
# Generation 42: Best Score = 0.3797277165272821, Best Individual = [-0.04395579 -0.6146508 ]
# Generation 43: Best Score = 2.2809076493775553, Best Individual = [1.02152012 1.11238676]
# Generation 44: Best Score = 1.611734098244972, Best Individual = [-0.55505108 -1.14177598]
# Generation 45: Best Score = 1.2382339083379645, Best Individual = [1.10061842 0.16392985]
# Generation 46: Best Score = 0.22754533041551944, Best Individual = [ 0.22321217 -0.42157047]
# Generation 47: Best Score = 0.05293012212276438, Best Individual = [0.12486676 0.19323151]
# Generation 48: Best Score = 0.22240261330132557, Best Individual = [ 0.18867978 -0.43220661]
# Generation 49: Best Score = 0.15545091276511072, Best Individual = [-0.09113815 -0.38359451]
# Generation 50: Best Score = 3.474758408011452, Best Individual = [-1.75353428 -0.63235745]
# Generation 51: Best Score = 1.085581532603153, Best Individual = [-1.04186859 -0.00955939]
# Generation 52: Best Score = 0.1433956725007232, Best Individual = [0.29531647 0.23703133]
# Generation 53: Best Score = 1.4700447450956082, Best Individual = [0.18821062 1.19775687]
# Generation 54: Best Score = 0.9038499496540956, Best Individual = [-0.93649358  0.16379779]
# Generation 55: Best Score = 0.45612439814513955, Best Individual = [ 0.29508782 -0.60749286]
# Generation 56: Best Score = 1.4675810966076044, Best Individual = [0.26664522 1.18172815]
# Generation 57: Best Score = 3.1771799663337785, Best Individual = [1.7170247  0.47854587]
# Generation 58: Best Score = 0.028497161287226198, Best Individual = [-0.07450159 -0.1514816 ]
# Generation 59: Best Score = 0.49380131185301746, Best Individual = [ 0.6899575 -0.1332665]
# Generation 60: Best Score = 0.42144382096104965, Best Individual = [ 0.10032612 -0.64138794]
# Generation 61: Best Score = 0.3771107267726873, Best Individual = [0.48787337 0.37294812]
# Generation 62: Best Score = 0.5199543924249753, Best Individual = [-0.51651633  0.50315532]
# Generation 63: Best Score = 0.35106807053650957, Best Individual = [-0.51489158  0.29318037]
# Generation 64: Best Score = 0.2888180633670526, Best Individual = [-0.40694904 -0.3510136 ]
# Generation 65: Best Score = 0.3161389073052612, Best Individual = [0.30448234 0.4726832 ]
# Generation 66: Best Score = 0.06721732341764326, Best Individual = [0.08443239 0.24512955]
# Generation 67: Best Score = 0.4913130730404799, Best Individual = [ 0.43457613 -0.5499606 ]
# Generation 68: Best Score = 0.07600871012909659, Best Individual = [-0.00748993  0.27559501]
# Generation 69: Best Score = 0.2930079450085849, Best Individual = [0.10154959 0.53169129]
# Generation 70: Best Score = 0.09142687619565452, Best Individual = [-0.16545473  0.25308419]
# Generation 71: Best Score = 0.37629746852625146, Best Individual = [0.02380381 0.61296888]
# Generation 72: Best Score = 0.0159921554866803, Best Individual = [0.08952729 0.08931416]
# Generation 73: Best Score = 0.18702162440245626, Best Individual = [-0.06569865 -0.42744042]
# Generation 74: Best Score = 0.44247235153769365, Best Individual = [ 0.14506294 -0.6491757 ]
# Generation 75: Best Score = 0.06407435755890004, Best Individual = [ 0.13159278 -0.21623528]
# Generation 76: Best Score = 0.488930319508796, Best Individual = [ 0.52774093 -0.45871541]
# Generation 77: Best Score = 0.7632011339439363, Best Individual = [0.63882414 0.59590675]
# Generation 78: Best Score = 0.015038837616450092, Best Individual = [-0.09098332  0.08222453]
# Generation 79: Best Score = 0.2777810244577905, Best Individual = [ 0.24160229 -0.46841153]
# Generation 80: Best Score = 0.19355179267015338, Best Individual = [-0.41010702  0.15926088]
# Generation 81: Best Score = 0.09357283301658006, Best Individual = [ 0.0693516  -0.29793152]
# Generation 82: Best Score = 0.22496527116433346, Best Individual = [ 0.22808489 -0.41586363]
# Generation 83: Best Score = 0.036648718243530075, Best Individual = [-0.1911247  -0.01095748]
# Generation 84: Best Score = 0.043316102811280406, Best Individual = [0.01807681 0.20733869]
# Generation 85: Best Score = 0.015691151248428375, Best Individual = [0.06987277 0.10396609]
# Generation 86: Best Score = 0.02543602963480014, Best Individual = [-0.15744124  0.02546144]
# Generation 87: Best Score = 0.05794161401646593, Best Individual = [-0.22282886  0.09104348]
# Generation 88: Best Score = 0.06099869526204356, Best Individual = [ 0.12191346 -0.21479247]
# Generation 89: Best Score = 0.07035562553969152, Best Individual = [ 0.15412455 -0.21587322]
# Generation 90: Best Score = 0.11789926259812368, Best Individual = [-0.23907582  0.24645896]
# Generation 91: Best Score = 0.09661969454005377, Best Individual = [-0.15435452 -0.26980433]
# Generation 92: Best Score = 0.22600181543318262, Best Individual = [-0.32104102  0.35062014]
# Generation 93: Best Score = 0.02217166903620721, Best Individual = [-0.13917106  0.05294416]
# Generation 94: Best Score = 0.06685015451709546, Best Individual = [-0.17402969  0.19121668]
# Generation 95: Best Score = 0.0715276463372822, Best Individual = [0.2396856  0.11865268]
# Generation 96: Best Score = 0.1391479106830557, Best Individual = [-0.36829276  0.05923137]
# Generation 97: Best Score = 0.18121689487650028, Best Individual = [ 0.40384261 -0.13464042]
# Generation 98: Best Score = 0.03930349697967532, Best Individual = [ 0.03895952 -0.19438532]
# Generation 99: Best Score = 0.08123350794656717, Best Individual = [-0.04399509 -0.2815989 ]
# Generation 100: Best Score = 0.056031223394469816, Best Individual = [-0.23600467 -0.01824887]
#
# Best solution: [-0.23600467 -0.01824887]
# Best objective function value: 0.056031223394469816
