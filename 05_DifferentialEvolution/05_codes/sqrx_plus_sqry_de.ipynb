# %%
import numpy as np

# Fungsi objektif yang ingin diminimalkan
def objective_function(X):
    x, y = X
    return x**2 + y**2

# Parameter DE
population_size = 4  # Ukuran populasi
F = 0.8  # Faktor skala
CR = 0.9  # Probabilitas crossover
generations = 100  # Jumlah generasi

# Batas pencarian
bounds = [(-5, 5), (-5, 5)]

# Inisialisasi populasi
def initialize_population(population_size, bounds):
    population = []
    for _ in range(population_size):
        individual = [np.random.uniform(low, high) for (low, high) in bounds]
        population.append(individual)
    return np.array(population)

# DE algoritma utama
def differential_evolution(objective_function, bounds, population_size, F, CR, generations):
    # Inisialisasi populasi
    population = initialize_population(population_size, bounds)
    for gen in range(generations):
        new_population = []
        for i in range(population_size):
            # Pilih tiga individu acak yang berbeda dari i
            indices = list(range(population_size))
            indices.remove(i)
            r1, r2, r3 = np.random.choice(indices, 3, replace=False)
            
            # Mutasi
            mutant_vector = population[r1] + F * (population[r2] - population[r3])
            
            # Rekombinasi
            trial_vector = []
            for j in range(len(bounds)):
                if np.random.rand() < CR:
                    trial_vector.append(mutant_vector[j])
                else:
                    trial_vector.append(population[i][j])
            trial_vector = np.array(trial_vector)
            
            # Seleksi
            if objective_function(trial_vector) < objective_function(population[i]):
                new_population.append(trial_vector)
            else:
                new_population.append(population[i])
        
        # Update populasi
        population = np.array(new_population)
        
        # Output hasil setiap generasi
        best_individual = population[np.argmin([objective_function(ind) for ind in population])]
        best_score = objective_function(best_individual)
        print(f"Generation {gen+1}: Best Score = {best_score}, Best Individual = {best_individual}")

    # Hasil akhir
    best_individual = population[np.argmin([objective_function(ind) for ind in population])]
    best_score = objective_function(best_individual)
    return best_individual, best_score

# Jalankan algoritma
best_individual, best_score = differential_evolution(objective_function, bounds, population_size, F, CR, generations)
print("\nBest solution:", best_individual)
print("Best objective function value:", best_score)
# Out:
# Generation 1: Best Score = 2.060317323976635, Best Individual = [ 0.70394148 -1.25091315]
# Generation 2: Best Score = 2.060317323976635, Best Individual = [ 0.70394148 -1.25091315]
# Generation 3: Best Score = 2.060317323976635, Best Individual = [ 0.70394148 -1.25091315]
# Generation 4: Best Score = 2.060317323976635, Best Individual = [ 0.70394148 -1.25091315]
# Generation 5: Best Score = 2.060317323976635, Best Individual = [ 0.70394148 -1.25091315]
# Generation 6: Best Score = 1.0658950316030196, Best Individual = [-0.96723886  0.36103188]
# Generation 7: Best Score = 1.0658950316030196, Best Individual = [-0.96723886  0.36103188]
# Generation 8: Best Score = 0.28312625779692424, Best Individual = [-0.43349676  0.30855602]
# Generation 9: Best Score = 0.18175215001106843, Best Individual = [-0.36561394 -0.21926833]
# Generation 10: Best Score = 0.18175215001106843, Best Individual = [-0.36561394 -0.21926833]
# Generation 11: Best Score = 0.18175215001106843, Best Individual = [-0.36561394 -0.21926833]
# Generation 12: Best Score = 0.18175215001106843, Best Individual = [-0.36561394 -0.21926833]
# Generation 13: Best Score = 0.08006948333582342, Best Individual = [-0.26521152  0.09865259]
# Generation 14: Best Score = 0.08006948333582342, Best Individual = [-0.26521152  0.09865259]
# Generation 15: Best Score = 0.031016486739794458, Best Individual = [0.11216151 0.13578027]
# Generation 16: Best Score = 0.031016486739794458, Best Individual = [0.11216151 0.13578027]
# Generation 17: Best Score = 0.031016486739794458, Best Individual = [0.11216151 0.13578027]
# Generation 18: Best Score = 0.031016486739794458, Best Individual = [0.11216151 0.13578027]
# Generation 19: Best Score = 0.031016486739794458, Best Individual = [0.11216151 0.13578027]
# Generation 20: Best Score = 0.031016486739794458, Best Individual = [0.11216151 0.13578027]
# Generation 21: Best Score = 0.031016486739794458, Best Individual = [0.11216151 0.13578027]
# Generation 22: Best Score = 0.026433087335441453, Best Individual = [-0.13717095  0.08727668]
# Generation 23: Best Score = 0.026433087335441453, Best Individual = [-0.13717095  0.08727668]
# Generation 24: Best Score = 0.006136707865091259, Best Individual = [-0.06846718  0.03806512]
# Generation 25: Best Score = 0.006136707865091259, Best Individual = [-0.06846718  0.03806512]
# Generation 26: Best Score = 0.006136707865091259, Best Individual = [-0.06846718  0.03806512]
# Generation 27: Best Score = 0.006136707865091259, Best Individual = [-0.06846718  0.03806512]
# Generation 28: Best Score = 0.0017256397696125236, Best Individual = [-0.03481794  0.02265725]
# Generation 29: Best Score = 0.0006563649419592744, Best Individual = [0.01195885 0.02265725]
# Generation 30: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 31: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 32: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 33: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 34: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 35: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 36: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 37: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 38: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 39: Best Score = 0.00015072690258184458, Best Individual = [-0.01224369  0.00090498]
# Generation 40: Best Score = 7.899473156726954e-05, Best Individual = [-0.00286409 -0.00841378]
# Generation 41: Best Score = 7.899473156726954e-05, Best Individual = [-0.00286409 -0.00841378]
# Generation 42: Best Score = 4.95830849815907e-05, Best Individual = [ 0.00029004 -0.00703555]
# Generation 43: Best Score = 3.578548808123145e-05, Best Individual = [-0.00571291 -0.0017743 ]
# Generation 44: Best Score = 3.578548808123145e-05, Best Individual = [-0.00571291 -0.0017743 ]
# Generation 45: Best Score = 1.5763786321770545e-05, Best Individual = [-0.00355185 -0.0017743 ]
# Generation 46: Best Score = 1.5763786321770545e-05, Best Individual = [-0.00355185 -0.0017743 ]
# Generation 47: Best Score = 9.191005250695067e-06, Best Individual = [-0.00012429  0.00302912]
# Generation 48: Best Score = 9.191005250695067e-06, Best Individual = [-0.00012429  0.00302912]
# Generation 49: Best Score = 1.442898738276358e-06, Best Individual = [-0.00116687  0.00028515]
# Generation 50: Best Score = 1.442898738276358e-06, Best Individual = [-0.00116687  0.00028515]
# Generation 51: Best Score = 1.442898738276358e-06, Best Individual = [-0.00116687  0.00028515]
# Generation 52: Best Score = 1.442898738276358e-06, Best Individual = [-0.00116687  0.00028515]
# Generation 53: Best Score = 1.442898738276358e-06, Best Individual = [-0.00116687  0.00028515]
# Generation 54: Best Score = 1.442898738276358e-06, Best Individual = [-0.00116687  0.00028515]
# Generation 55: Best Score = 1.442898738276358e-06, Best Individual = [-0.00116687  0.00028515]
# Generation 56: Best Score = 1.3995580889234465e-06, Best Individual = [-0.000914    0.00075111]
# Generation 57: Best Score = 1.3995580889234465e-06, Best Individual = [-0.000914    0.00075111]
# Generation 58: Best Score = 1.3995580889234465e-06, Best Individual = [-0.000914    0.00075111]
# Generation 59: Best Score = 3.603200632796009e-07, Best Individual = [-0.000463    0.00038204]
# Generation 60: Best Score = 1.7975239771142597e-08, Best Individual = [-1.02202129e-04  8.67753680e-05]
# Generation 61: Best Score = 1.7975239771142597e-08, Best Individual = [-1.02202129e-04  8.67753680e-05]
# Generation 62: Best Score = 1.7975239771142597e-08, Best Individual = [-1.02202129e-04  8.67753680e-05]
# Generation 63: Best Score = 1.7975239771142597e-08, Best Individual = [-1.02202129e-04  8.67753680e-05]
# Generation 64: Best Score = 1.1238567728957029e-08, Best Individual = [-6.08983024e-05  8.67753680e-05]
# Generation 65: Best Score = 1.1238567728957029e-08, Best Individual = [-6.08983024e-05  8.67753680e-05]
# Generation 66: Best Score = 1.1238567728957029e-08, Best Individual = [-6.08983024e-05  8.67753680e-05]
# Generation 67: Best Score = 1.1238567728957029e-08, Best Individual = [-6.08983024e-05  8.67753680e-05]
# Generation 68: Best Score = 9.867107376826875e-09, Best Individual = [-1.58356195e-05  9.80629417e-05]
# Generation 69: Best Score = 9.867107376826875e-09, Best Individual = [-1.58356195e-05  9.80629417e-05]
# Generation 70: Best Score = 9.867107376826875e-09, Best Individual = [-1.58356195e-05  9.80629417e-05]
# Generation 71: Best Score = 3.0817683127499106e-09, Best Individual = [ 5.30914888e-05 -1.62191902e-05]
# Generation 72: Best Score = 2.0291939576090257e-09, Best Individual = [-2.95530540e-05 -3.39972199e-05]
# Generation 73: Best Score = 2.0291939576090257e-09, Best Individual = [-2.95530540e-05 -3.39972199e-05]
# Generation 74: Best Score = 1.380101898305481e-09, Best Individual = [-3.58221037e-05 -9.84270229e-06]
# Generation 75: Best Score = 5.544608140118916e-10, Best Individual = [ 1.70704037e-05 -1.62191902e-05]
# Generation 76: Best Score = 5.544608140118916e-10, Best Individual = [ 1.70704037e-05 -1.62191902e-05]
# Generation 77: Best Score = 5.544608140118916e-10, Best Individual = [ 1.70704037e-05 -1.62191902e-05]
# Generation 78: Best Score = 5.544608140118916e-10, Best Individual = [ 1.70704037e-05 -1.62191902e-05]
# Generation 79: Best Score = 5.544608140118916e-10, Best Individual = [ 1.70704037e-05 -1.62191902e-05]
# Generation 80: Best Score = 5.544608140118916e-10, Best Individual = [ 1.70704037e-05 -1.62191902e-05]
# Generation 81: Best Score = 1.9775259884977733e-10, Best Individual = [-1.97089894e-06 -1.39236546e-05]
# Generation 82: Best Score = 1.9775259884977733e-10, Best Individual = [-1.97089894e-06 -1.39236546e-05]
# Generation 83: Best Score = 1.294874537335741e-10, Best Individual = [ 1.13656517e-05 -5.56251345e-07]
# Generation 84: Best Score = 1.294874537335741e-10, Best Individual = [ 1.13656517e-05 -5.56251345e-07]
# Generation 85: Best Score = 1.294874537335741e-10, Best Individual = [ 1.13656517e-05 -5.56251345e-07]
# Generation 86: Best Score = 1.294874537335741e-10, Best Individual = [ 1.13656517e-05 -5.56251345e-07]
# Generation 87: Best Score = 5.3328748126631105e-12, Best Individual = [1.35071907e-06 1.87308110e-06]
# Generation 88: Best Score = 5.3328748126631105e-12, Best Individual = [1.35071907e-06 1.87308110e-06]
# Generation 89: Best Score = 5.3328748126631105e-12, Best Individual = [1.35071907e-06 1.87308110e-06]
# Generation 90: Best Score = 5.3328748126631105e-12, Best Individual = [1.35071907e-06 1.87308110e-06]
# Generation 91: Best Score = 5.3328748126631105e-12, Best Individual = [1.35071907e-06 1.87308110e-06]
# Generation 92: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 93: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 94: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 95: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 96: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 97: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 98: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 99: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
# Generation 100: Best Score = 4.206098721999492e-12, Best Individual = [ 3.25711397e-07 -2.02484834e-06]
#
# Best solution: [ 3.25711397e-07 -2.02484834e-06]
# Best objective function value: 4.206098721999492e-12

# %% [markdown]
# ## Penjelasan Kode
#
# 1. **Inisialisasi Populasi**: Populasi diinisialisasi secara acak dalam batas yang ditentukan oleh `bounds`.
#
# 2. **Proses Utama DE**:
#    - Untuk setiap individu dalam populasi, tiga individu acak yang berbeda dipilih.
#    - **Mutasi**: Vektor mutasi dihitung menggunakan rumus $V_i = X_{r1} + F \cdot (X_{r2} - X_{r3})$.
#    - **Rekombinasi**: Vektor uji dihasilkan dari kombinasi elemen antara vektor mutasi dan vektor target dengan probabilitas crossover $CR$.
#    - **Seleksi**: Individu dengan nilai fungsi objektif yang lebih baik (antara vektor uji dan vektor target) dipilih untuk generasi berikutnya.
#
# 3. **Iterasi Generasi**: Proses berlanjut hingga mencapai jumlah generasi yang ditentukan.
#
# 4. **Output Hasil Akhir**: Menampilkan individu terbaik dan nilai fungsi objektif terendah setelah semua generasi.
#
# ### Menjalankan Kode
# Setelah menjalankan kode ini, Anda akan melihat hasil terbaik untuk setiap generasi, dan pada akhirnya, solusi terbaik yang ditemukan oleh DE untuk masalah ini.
