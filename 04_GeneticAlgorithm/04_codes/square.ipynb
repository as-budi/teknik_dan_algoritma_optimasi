# %%
import random

# Fungsi fitness untuk f(x) = x^2
def fitness(x):
    return x**2  # Kita ingin meminimalkan fungsi ini

# Inisialisasi populasi
def init_population(size, lower_bound, upper_bound):
    return [random.uniform(lower_bound, upper_bound) for _ in range(size)]

# Seleksi dengan Tournament Selection
def tournament_selection(population, tournament_size=2):
    selected = random.sample(population, tournament_size)
    return min(selected, key=fitness)  # Mengembalikan individu dengan fitness terbaik

# Crossover
def crossover(parent1, parent2):
    crossover_point = random.random()
    return crossover_point * parent1 + (1 - crossover_point) * parent2, (1 - crossover_point) * parent1 + crossover_point * parent2

# Mutasi
def mutate(individual, mutation_rate=0.1):
    if random.random() < mutation_rate:
        mutation_amount = random.uniform(-1, 1)  # Rentang mutasi
        return individual + mutation_amount
    return individual

# Algoritma Genetik
def genetic_algorithm(num_generations, population_size, mutation_rate, lower_bound, upper_bound):
    population = init_population(population_size, lower_bound, upper_bound)
    
    for generation in range(num_generations):
        new_population = []
        
        for _ in range(population_size // 2):  # Asumsi kita menggunakan pasangan untuk crossover
            parent1 = tournament_selection(population)
            parent2 = tournament_selection(population)
            offspring1, offspring2 = crossover(parent1, parent2)
            new_population.append(mutate(offspring1, mutation_rate))
            new_population.append(mutate(offspring2, mutation_rate))
        
        population = new_population

        # Menampilkan fitness terbaik di setiap generasi
        best_fitness = min(fitness(ind) for ind in population)
        print(f"Generasi {generation + 1}: Fitness Terbaik = {best_fitness}")

    best_solution = min(population, key=fitness)
    return best_solution, fitness(best_solution)

# Parameter
num_generations = 100
population_size = 20
mutation_rate = 0.1
lower_bound = -10
upper_bound = 10

# Menjalankan algoritma genetik
best_solution, best_fitness = genetic_algorithm(num_generations, population_size, mutation_rate, lower_bound, upper_bound)

# Menampilkan hasil akhir
print("Individu Terbaik:", best_solution)
print("Fitness Terbaik:", best_fitness)
# Out:
# Generasi 1: Fitness Terbaik = 0.06009492013754136
# Generasi 2: Fitness Terbaik = 0.0036679402143215403
# Generasi 3: Fitness Terbaik = 0.0030889869044904562
# Generasi 4: Fitness Terbaik = 0.00049293721409982
# Generasi 5: Fitness Terbaik = 1.1783098996951998e-07
# Generasi 6: Fitness Terbaik = 7.077374850765436e-05
# Generasi 7: Fitness Terbaik = 0.0002323772363451427
# Generasi 8: Fitness Terbaik = 2.4405503350784856e-06
# Generasi 9: Fitness Terbaik = 8.01942183247816e-06
# Generasi 10: Fitness Terbaik = 5.457161753333387e-05
# Generasi 11: Fitness Terbaik = 1.3198136439888742e-08
# Generasi 12: Fitness Terbaik = 5.0847513462134755e-09
# Generasi 13: Fitness Terbaik = 1.0176630677912642e-07
# Generasi 14: Fitness Terbaik = 1.0303395174801021e-11
# Generasi 15: Fitness Terbaik = 6.860716641894487e-11
# Generasi 16: Fitness Terbaik = 3.679710166955667e-10
# Generasi 17: Fitness Terbaik = 3.843469697721307e-10
# Generasi 18: Fitness Terbaik = 4.979731186835022e-13
# Generasi 19: Fitness Terbaik = 4.979731186835022e-13
# Generasi 20: Fitness Terbaik = 1.109417441046714e-13
# Generasi 21: Fitness Terbaik = 2.0905229163932162e-14
# Generasi 22: Fitness Terbaik = 2.329687902752987e-14
# Generasi 23: Fitness Terbaik = 1.6175209932293546e-14
# Generasi 24: Fitness Terbaik = 3.3272977769170403e-15
# Generasi 25: Fitness Terbaik = 8.279935584344556e-15
# Generasi 26: Fitness Terbaik = 2.5972083915546785e-15
# Generasi 27: Fitness Terbaik = 5.963268001347222e-16
# Generasi 28: Fitness Terbaik = 5.021696774090184e-18
# Generasi 29: Fitness Terbaik = 2.228620562775514e-19
# Generasi 30: Fitness Terbaik = 3.2520399186523113e-19
# Generasi 31: Fitness Terbaik = 8.20225059610007e-18
# Generasi 32: Fitness Terbaik = 8.276355698929071e-18
# Generasi 33: Fitness Terbaik = 2.395997335604358e-17
# Generasi 34: Fitness Terbaik = 2.737471202276926e-17
# Generasi 35: Fitness Terbaik = 2.7530405043262924e-17
# Generasi 36: Fitness Terbaik = 2.787689764236465e-17
# Generasi 37: Fitness Terbaik = 2.7878275863254777e-17
# Generasi 38: Fitness Terbaik = 2.788275956905565e-17
# Generasi 39: Fitness Terbaik = 2.791731399945527e-17
# Generasi 40: Fitness Terbaik = 2.797263027783584e-17
# Generasi 41: Fitness Terbaik = 2.802056518256557e-17
# Generasi 42: Fitness Terbaik = 2.8075288057956914e-17
# Generasi 43: Fitness Terbaik = 2.8079488583674057e-17
# Generasi 44: Fitness Terbaik = 2.808136549160354e-17
# Generasi 45: Fitness Terbaik = 2.8083378327655674e-17
# Generasi 46: Fitness Terbaik = 2.808389534499975e-17
# Generasi 47: Fitness Terbaik = 2.808812379024263e-17
# Generasi 48: Fitness Terbaik = 2.808835982954032e-17
# Generasi 49: Fitness Terbaik = 2.808888976875599e-17
# Generasi 50: Fitness Terbaik = 2.8088978693514635e-17
# Generasi 51: Fitness Terbaik = 2.808920036139705e-17
# Generasi 52: Fitness Terbaik = 2.8089759165780675e-17
# Generasi 53: Fitness Terbaik = 2.8089771483150295e-17
# Generasi 54: Fitness Terbaik = 2.8089771483150295e-17
# Generasi 55: Fitness Terbaik = 2.8089771483150295e-17
# Generasi 56: Fitness Terbaik = 2.8089772814054754e-17
# Generasi 57: Fitness Terbaik = 2.808977402546128e-17
# Generasi 58: Fitness Terbaik = 2.808977456275219e-17
# Generasi 59: Fitness Terbaik = 2.808977471567267e-17
# Generasi 60: Fitness Terbaik = 2.8089775513926826e-17
# Generasi 61: Fitness Terbaik = 2.8089775513926826e-17
# Generasi 62: Fitness Terbaik = 2.808977552734918e-17
# Generasi 63: Fitness Terbaik = 2.8089775535570156e-17
# Generasi 64: Fitness Terbaik = 2.808977559217757e-17
# Generasi 65: Fitness Terbaik = 2.808977559217757e-17
# Generasi 66: Fitness Terbaik = 2.808977559217757e-17
# Generasi 67: Fitness Terbaik = 2.8089775595250744e-17
# Generasi 68: Fitness Terbaik = 2.80897756018966e-17
# Generasi 69: Fitness Terbaik = 2.8089775601918264e-17
# Generasi 70: Fitness Terbaik = 2.8089775601918264e-17
# Generasi 71: Fitness Terbaik = 2.8089775601918264e-17
# Generasi 72: Fitness Terbaik = 2.8089775601918264e-17
# Generasi 73: Fitness Terbaik = 2.8089775601918264e-17
# Generasi 74: Fitness Terbaik = 2.8089775601919065e-17
# Generasi 75: Fitness Terbaik = 2.808977560192177e-17
# Generasi 76: Fitness Terbaik = 2.808977560192183e-17
# Generasi 77: Fitness Terbaik = 2.808977560192183e-17
# Generasi 78: Fitness Terbaik = 2.808977560192196e-17
# Generasi 79: Fitness Terbaik = 2.8089775601922085e-17
# Generasi 80: Fitness Terbaik = 2.8089775601922085e-17
# Generasi 81: Fitness Terbaik = 2.808977560192212e-17
# Generasi 82: Fitness Terbaik = 2.808977560192216e-17
# Generasi 83: Fitness Terbaik = 2.808977560192221e-17
# Generasi 84: Fitness Terbaik = 2.8089775601922245e-17
# Generasi 85: Fitness Terbaik = 2.8089775601922245e-17
# Generasi 86: Fitness Terbaik = 2.8089775601922264e-17
# Generasi 87: Fitness Terbaik = 2.8089775601922264e-17
# Generasi 88: Fitness Terbaik = 2.808977560192227e-17
# Generasi 89: Fitness Terbaik = 2.808977560192227e-17
# Generasi 90: Fitness Terbaik = 2.808977560192228e-17
# Generasi 91: Fitness Terbaik = 2.808977560192228e-17
# Generasi 92: Fitness Terbaik = 2.808977560192228e-17
# Generasi 93: Fitness Terbaik = 2.808977560192228e-17
# Generasi 94: Fitness Terbaik = 2.808977560192228e-17
# Generasi 95: Fitness Terbaik = 2.808977560192228e-17
# Generasi 96: Fitness Terbaik = 2.808977560192228e-17
# Generasi 97: Fitness Terbaik = 2.808977560192228e-17
# Generasi 98: Fitness Terbaik = 2.808977560192228e-17
# Generasi 99: Fitness Terbaik = 2.808977560192228e-17
# Generasi 100: Fitness Terbaik = 2.808977560192228e-17
# Individu Terbaik: -5.299978830327748e-09
# Fitness Terbaik: 2.808977560192228e-17
