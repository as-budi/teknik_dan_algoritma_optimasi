# %%
import random

# Fungsi fitness untuk f(x) = x^2 + 5x + 10
def fitness(x):
    return x**2 + 5*x + 10  # Kita ingin meminimalkan fungsi ini

# Inisialisasi populasi
def init_population(size, lower_bound, upper_bound):
    return [random.uniform(lower_bound, upper_bound) for _ in range(size)]

# Seleksi dengan Tournament Selection
def tournament_selection(population, tournament_size=2):
    selected = random.sample(population, tournament_size)
    return min(selected, key=fitness)  # Mengembalikan individu dengan fitness terbaik

# Crossover
def crossover(parent1, parent2):
    crossover_point = random.random()
    return crossover_point * parent1 + (1 - crossover_point) * parent2, (1 - crossover_point) * parent1 + crossover_point * parent2

# Mutasi
def mutate(individual, mutation_rate=0.1):
    if random.random() < mutation_rate:
        mutation_amount = random.uniform(-1, 1)  # Rentang mutasi
        return individual + mutation_amount
    return individual

# Algoritma Genetik
def genetic_algorithm(num_generations, population_size, mutation_rate, lower_bound, upper_bound):
    population = init_population(population_size, lower_bound, upper_bound)
    
    for generation in range(num_generations):
        new_population = []
        
        for _ in range(population_size // 2):  # Asumsi kita menggunakan pasangan untuk crossover
            parent1 = tournament_selection(population)
            parent2 = tournament_selection(population)
            offspring1, offspring2 = crossover(parent1, parent2)
            new_population.append(mutate(offspring1, mutation_rate))
            new_population.append(mutate(offspring2, mutation_rate))
        
        population = new_population

        # Menampilkan fitness terbaik di setiap generasi
        best_fitness = min(fitness(ind) for ind in population)
        print(f"Generasi {generation + 1}: Fitness Terbaik = {best_fitness}")

    best_solution = min(population, key=fitness)
    return best_solution, fitness(best_solution)

# Parameter
num_generations = 100
population_size = 20
mutation_rate = 0.1
lower_bound = -10
upper_bound = 10

# Menjalankan algoritma genetik
best_solution, best_fitness = genetic_algorithm(num_generations, population_size, mutation_rate, lower_bound, upper_bound)

# Menampilkan hasil akhir
print("Individu Terbaik:", best_solution)
print("Fitness Terbaik:", best_fitness)
# Out:
# Generasi 1: Fitness Terbaik = 3.7504414252896936
# Generasi 2: Fitness Terbaik = 3.7819003411629977
# Generasi 3: Fitness Terbaik = 3.7864796041570514
# Generasi 4: Fitness Terbaik = 3.750560557308635
# Generasi 5: Fitness Terbaik = 3.7500086654028015
# Generasi 6: Fitness Terbaik = 3.7500026194262475
# Generasi 7: Fitness Terbaik = 3.750022232983559
# Generasi 8: Fitness Terbaik = 3.7500001050517318
# Generasi 9: Fitness Terbaik = 3.750000048752092
# Generasi 10: Fitness Terbaik = 3.750000048752092
# Generasi 11: Fitness Terbaik = 3.750003744798221
# Generasi 12: Fitness Terbaik = 3.750006326585214
# Generasi 13: Fitness Terbaik = 3.7500077354958608
# Generasi 14: Fitness Terbaik = 3.750009101020048
# Generasi 15: Fitness Terbaik = 3.7500091032497265
# Generasi 16: Fitness Terbaik = 3.750009125314598
# Generasi 17: Fitness Terbaik = 3.750009176363384
# Generasi 18: Fitness Terbaik = 3.750009199253383
# Generasi 19: Fitness Terbaik = 3.7500092813088077
# Generasi 20: Fitness Terbaik = 3.7500092930480955
# Generasi 21: Fitness Terbaik = 3.750009295320239
# Generasi 22: Fitness Terbaik = 3.7500092973372867
# Generasi 23: Fitness Terbaik = 3.7500093207117358
# Generasi 24: Fitness Terbaik = 3.7500093223189257
# Generasi 25: Fitness Terbaik = 3.7500093223189257
# Generasi 26: Fitness Terbaik = 3.7500093223189257
# Generasi 27: Fitness Terbaik = 3.7500093226800253
# Generasi 28: Fitness Terbaik = 3.750009323596389
# Generasi 29: Fitness Terbaik = 3.7500093288986793
# Generasi 30: Fitness Terbaik = 3.7500093289880194
# Generasi 31: Fitness Terbaik = 3.7500093289913794
# Generasi 32: Fitness Terbaik = 3.750009328994337
# Generasi 33: Fitness Terbaik = 3.750009329021143
# Generasi 34: Fitness Terbaik = 3.7500093290265335
# Generasi 35: Fitness Terbaik = 3.7500093290293837
# Generasi 36: Fitness Terbaik = 3.750009329029874
# Generasi 37: Fitness Terbaik = 3.7500093290312027
# Generasi 38: Fitness Terbaik = 3.750009329033067
# Generasi 39: Fitness Terbaik = 3.7500093290330803
# Generasi 40: Fitness Terbaik = 3.7500093290330803
# Generasi 41: Fitness Terbaik = 3.750009329033081
# Generasi 42: Fitness Terbaik = 3.7500093290330865
# Generasi 43: Fitness Terbaik = 3.7500093290330856
# Generasi 44: Fitness Terbaik = 3.75000932903309
# Generasi 45: Fitness Terbaik = 3.75000932903309
# Generasi 46: Fitness Terbaik = 3.750009329033091
# Generasi 47: Fitness Terbaik = 3.7500093290330936
# Generasi 48: Fitness Terbaik = 3.7500093290330954
# Generasi 49: Fitness Terbaik = 3.7500093290330954
# Generasi 50: Fitness Terbaik = 3.7500093290330954
# Generasi 51: Fitness Terbaik = 3.7500093290330954
# Generasi 52: Fitness Terbaik = 3.750009329033097
# Generasi 53: Fitness Terbaik = 3.750009329033097
# Generasi 54: Fitness Terbaik = 3.750009329033097
# Generasi 55: Fitness Terbaik = 3.750009329033097
# Generasi 56: Fitness Terbaik = 3.750009329033097
# Generasi 57: Fitness Terbaik = 3.750009329033097
# Generasi 58: Fitness Terbaik = 3.750009329033097
# Generasi 59: Fitness Terbaik = 3.750009329033097
# Generasi 60: Fitness Terbaik = 3.750009329033097
# Generasi 61: Fitness Terbaik = 3.750009329033097
# Generasi 62: Fitness Terbaik = 3.750009329033097
# Generasi 63: Fitness Terbaik = 3.750009329033097
# Generasi 64: Fitness Terbaik = 3.750009329033097
# Generasi 65: Fitness Terbaik = 3.750009329033097
# Generasi 66: Fitness Terbaik = 3.750009329033097
# Generasi 67: Fitness Terbaik = 3.750009329033097
# Generasi 68: Fitness Terbaik = 3.750009329033097
# Generasi 69: Fitness Terbaik = 3.750009329033097
# Generasi 70: Fitness Terbaik = 3.750009329033097
# Generasi 71: Fitness Terbaik = 3.750009329033097
# Generasi 72: Fitness Terbaik = 3.750009329033097
# Generasi 73: Fitness Terbaik = 3.750009329033097
# Generasi 74: Fitness Terbaik = 3.750009329033097
# Generasi 75: Fitness Terbaik = 3.750009329033097
# Generasi 76: Fitness Terbaik = 3.750009329033097
# Generasi 77: Fitness Terbaik = 3.750009329033097
# Generasi 78: Fitness Terbaik = 3.750009329033097
# Generasi 79: Fitness Terbaik = 3.750009329033097
# Generasi 80: Fitness Terbaik = 3.750009329033097
# Generasi 81: Fitness Terbaik = 3.750009329033097
# Generasi 82: Fitness Terbaik = 3.750009329033097
# Generasi 83: Fitness Terbaik = 3.750009329033097
# Generasi 84: Fitness Terbaik = 3.750009329033097
# Generasi 85: Fitness Terbaik = 3.750009329033097
# Generasi 86: Fitness Terbaik = 3.7500008841451793
# Generasi 87: Fitness Terbaik = 3.7500009153939287
# Generasi 88: Fitness Terbaik = 3.750000179197933
# Generasi 89: Fitness Terbaik = 3.750000000371842
# Generasi 90: Fitness Terbaik = 3.7500001113491583
# Generasi 91: Fitness Terbaik = 3.7500000049418825
# Generasi 92: Fitness Terbaik = 3.750000012326316
# Generasi 93: Fitness Terbaik = 3.750000000056702
# Generasi 94: Fitness Terbaik = 3.7500000034531036
# Generasi 95: Fitness Terbaik = 3.750000000000001
# Generasi 96: Fitness Terbaik = 3.750000000038958
# Generasi 97: Fitness Terbaik = 3.7500000000282565
# Generasi 98: Fitness Terbaik = 3.7500000008743983
# Generasi 99: Fitness Terbaik = 3.7500000008743983
# Generasi 100: Fitness Terbaik = 3.7500000010961907
# Individu Terbaik: -2.500033108773442
# Fitness Terbaik: 3.7500000010961907
